# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup

url = "https://www.foodsafetykorea.go.kr/portal/healthyfoodlife/searchHomeHF.do?menu_grp=MENU_NEW01&menu_no=2823"
url2 = "https://www.foodsafetykorea.go.kr/portal/healthyfoodlife/searchHomeHFDetail.do"

detailURL = 'https://www.foodsafetykorea.go.kr/portal/healthyfoodlife/searchHomeHFDetail.do'

html = urlopen(url)
bsObject = BeautifulSoup(html, "html.parser")

print(bsObject)
# Out:
# <!DOCTYPE html>
#
# <html lang="ko">
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible" id="document_mode"/>
# <meta content="width=device-width,initial-scale=1.0,minimum-scale=1.0,maximum-scale=1.0" name="viewport">
# <title id="brwsTitle">식품안전나라</title>
# <link href="/css/2021/sub_2021.css" rel="stylesheet" type="text/css"/>
# <link href="/css/2021/search.css" rel="stylesheet" type="text/css"/>
# <link href="/js/2021/jquery.scrollbar.css" rel="stylesheet" type="text/css"/>
# <link href="/css/jquery.selecter.css" rel="stylesheet" type="text/css"/>
# <link href="/css/jquery.mCustomScrollbar.css" rel="stylesheet" type="text/css"/>
# <script src="/js/2021/jquery-1.11.3.min.js" type="text/javascript"></script>
# <script src="/js/2021/jquery-ui.min.js" type="text/javascript"></script>
# <script src="/js/2021/jquery.easing.1.3.js" type="text/javascript"></script>
# <script src="/js/2021/common.js" type="text/javascript"></script>
# <script src="/js/2021/fullpage.js" type="text/javascript"></script>
# <script src="/js/2021/plugins.js" type="text/javascript"></script>
# <script src="/js/2021/jquery.scrollbar.js" type="text/javascript"></script>
# <script src="/js/2021/html5.js" type="text/javascript"></script>
# <link href="/css/jquery.fancybox.css" rel="stylesheet" type="text/css">
# <link href="/css/nivo-slider.css" rel="stylesheet" type="text/css">
# <script src="/js/jquery.fancybox.js" type="text/javascript"></script>
# <script src="/js/jquery.selecter.min.js" type="text/javascript"></script>
# <script src="/js/jquery.simplePagination.js" type="text/javascript"></script>
# <script src="/js/jquery.nivo.slider.min.js" type="text/javascript"></script>
# <script src="/js/bootstrap.min.js" type="text/javascript"></script>
# <script src="/js/bootstrap/button.js" type="text/javascript"></script>
# <script src="/js/bootstrap/tab.js" type="text/javascript"></script>
# <script src="/js/jquery.cookie.min.js" type="text/javascript"></script>
# <script src="/js/search_autocomplete_common.js" type="text/javascript"></script>
# </link></link></meta></head>
# <body class="sub" onload="SearchCookieView();">
# <div>
# <div id="skipArea">
# <a href="#gnbMenu">메인메뉴 바로가기</a>
# <a href="#wrap">본문으로 바로가기</a>
# </div>
# <header id="header">
# <!-- top_link -->
# <div class="top_link">
# <h1 class="logo"><a href="/main.do"><img alt="식품안전정보포털 식품안전나라" src="/images/2021/common_2021/logo.png"/></a></h1>
# <!-- 검색 -->
# <div class="box_search">
# <!-- <form name="siteSearchForm" > -->
# <div class="siteSearchForm">
# <form id="searchForm" method="post" name="searchForm" onsubmit="return false;">
# <input id="searchMode1_searchForm" name="searchMode" type="hidden" value="search"/>
# <input id="currentPage_searchForm" name="currentPage" type="hidden" value="1"/>
# <input id="filterTarget_searchForm" name="filterTarget" type="hidden"/>
# <input id="trendGubun_searchForm" name="trendGubun" type="hidden"/>
# <input id="searchSort_searchForm" name="searchSort" type="hidden"/>
# <input id="addValue_searchForm" name="addValue" type="hidden"/>
# <input id="attachFilter_searchForm" name="attachFilter" type="hidden"/>
# <input id="attachFilterYn_searchForm" name="attachFilterYn" type="hidden"/>
# <input id="filePath_searchForm" name="filePath" type="hidden"/>
# <input id="fileName_searchForm" name="fileName" type="hidden"/>
# <input id="orgFileName_searchForm" name="orgFileName" type="hidden"/>
# <input id="headerCheck_searchForm" name="headerCheck" type="hidden" value="Y"/>
# <input id="reSearch_searchForm" name="reSearch" type="hidden" value=""/>
# <input id="colTarget_searchForm" name="colTarget" type="hidden" value="total"/>
# <input id="menu_no_searchForm" name="menu_no" type="hidden" value="3090"/>
# <input id="menu_grp_searchForm" name="menu_grp" type="hidden" value="MENU_NEW07"/>
# <label class="hid" for="pc_searchTopTerm">검색</label>
# <input autocomplete="off" class="all_search_text" id="pc_searchTopTerm" name="searchTopTerm" onfocus="return dqs_setTextbox('0',event);" onkeydown="dqs_setTextbox('1',event);" onkeypress="javascript:fn_searchKeyTop();" onmousedown="dqs_setTextbox('1',event);" placeholder="검색어를 입력해주세요" style="ime-mode:active;" title="검색어를 입력해주세요" type="text" value=""/>
# <!-- s: 최근검색어-->
# <div class="search_latest" tabindex="0">
# <strong>최근검색어</strong>
# <div class="search_ls_alert" id="search_ls_alert"><!-- style로 강제로 안보이게 해놓은 것이므로 개발완료 후 style은 삭제할 것. -->
# <i>알림</i>
# <strong>검색어 저장 기능이 꺼져 있습니다.</strong>
# <span>하단 <b>‘기능켜기’</b> 버튼을 눌러 검색어 저장 기능을 활성화 할 수 있습니다.</span>
# </div>
# <div id="mykeyword">
# <ul class="search_ls_word">
# </ul>
# </div>
# <div class="search_latest_bottom">
# <input class="search_l_hisbtn" onclick="cookieDelete();" type="button" value="검색기록 삭제"/>
# <span class="search_l_line"></span>
# <input class="search_l_hisoff" id="hisoff" onclick="hisoffSetCookie();" type="button" value="기능켜기"/>
# </div>
# </div>
# <!-- e: 최근검색어-->
# <!-- s: 검색결과-->
# <div class="search_quick_result">
# <!-- s: 이슈검색-->
# <div class="search_hot">
# <strong id="thumnailCount">인기검색어</strong>
# <div class="search_qr_cont">
# <div class="search_qr_cont_scroll">
# <ul>
# </ul>
# </div>
# </div>
# </div>
# <!-- e: 이슈검색-->
# <!-- s: 자동완성-->
# <!-- <div id="ark"></div> -->
# <div class="search_autocom">
# <strong>자동완성</strong>
# <div class="search_qr_cont">
# <div class="search_qr_cont_scroll" id="autoTop_complete" onmouseout="dqs_setMouseoff();" onmouseover="dqs_setMouseon();">
# <!-- 자동완성 start -->
# <script src="/js/searchPortal_autocomplete.js"></script>
# <!--// 자동완성 end -->
# </div>
# </div>
# </div>
# <!-- e: 자동완성-->
# <!-- s: 키워드 수집기-->
# <div class="search_spot">
# <strong>스팟 검색</strong>
# <div class="search_qr_cont">
# <div class="search_qr_cont_scroll" id="vizCloud"></div>
# </div>
# </div>
# <!-- e: 키워드 수집기-->
# <div class="search_latest_bottom">
# <button class="search_l_close">자동완성 끄기</button>
# </div>
# </div>
# <!-- e: 검색결과-->
# <button class="search_btn" id="pc_search_btn" onclick="javascript:fn_searchTop();"><span>검색</span></button>
# </form>
# </div>
# </div>
# <!--// 검색 -->
# <!-- 모바일용 검색 레이아웃 -->
# <div class="search">
# <div class="wrap">
# <button class="search_open">통합검색 열기</button>
# <div class="search_panel">
# <h2 class="skip">통합검색</h2>
# <button class="search_close" type="button">통합검색 닫기</button>
# </div>
# </div>
# </div>
# <!-- // 모바일용 검색  -->
# <!-- 상세검색 레이어 -->
# <div class="all_search_extend">
# <strong>상세 검색 옵션</strong>
# <div class="ly_center_mom">
# <div class="all_search_inputs_box1">
# <strong class="all_search_tit">카테고리</strong>
# <div class="all_search_inputs_box"></div>
# </div>
# <div class="all_search_inputs_box2">
# <div class="field">
# <label class="all_search_tit" for="mustIncTermKeyword">반드시 포함하는 검색어(단어 포함)</label>
# <input id="mustIncTermKeyword" name="mustIncTermKeyword" type="text"/>
# </div>
# <div class="field">
# <label class="all_search_tit" for="excTermKeyword">제외 검색어(단어 포함)</label>
# <input id="excTermKeyword" name="excTermKeyword" type="text"/>
# </div>
# <div class="field">
# <label class="all_search_tit" for="searchRange">검색 결과 기간 설정</label>
# <!-- div 감쌈-->
# <div class="ds_select_box">
# <select id="searchRange" name="searchRange">
# </select>
# </div>
# </div>
# <div class="field">
# <label class="all_search_tit" for="searchField">검색 범위 설정</label>
# <div class="ds_select_box">
# <select id="searchField" name="searchField">
# </select>
# </div>
# </div>
# <div class="search_btn_exsave">
# <button onclick="javascript:saveSearchTerm(event);">검색조건 저장</button>
# </div>
# </div>
# </div>
# <!-- e:ly_center_mom -->
# <button class="search_btn_close"><span>상세 검색 닫기</span></button>
# </div>
# <!-- // 상세검색 레이어 -->
# <!-- 우측상단 유틸메뉴  -->
# <div class="util_right">
# <ul class="clearfix">
# <li class=""><a href="/minwonMainNew.do" title="통합민원상담서비스">통합민원상담</a></li>
# <li><a href="/apiMain.do" title="공공데이터활용서비스">공공데이터</a></li>
# <li>
# <a href="httpS://www.foodsafetykorea.go.kr/portal/member/csmLoginNew.do?menu_no=3817&amp;menu_grp=MENU_NEW07" title="우리회사 안전관리서비스">우리회사 안전관리</a>
# </li>
# <li><a href="httpS://www.foodsafetykorea.go.kr/portal/loginNew.do?menu_no=3817&amp;menu_grp=MENU_NEW07" title="로그인">로그인</a></li>
# <li><a href="httpS://www.foodsafetykorea.go.kr/portal/member/joinAgreeView.do" title="회원가입">회원가입</a></li>
# <li class="zoom-element">
# <button class="zoom-in" onclick="zoomIn();" type="button">화면확대</button>
# <button class="zoom-out" onclick="zoomOut();" type="button">화면축소</button>
# </li>
# </ul>
# </div>
# <!-- // 우측상단 유틸메뉴  -->
# </div>
# <!-- // top_link -->
# <!-- gog 스크립트 살려야함 -->
# <div class="lnb" id="lnb">
# <div class="menu_show">
# <button class="menu_btn" type="button">주메뉴 열기</button>
# </div>
# <nav class="menu after eachdown">
# <h2 class="skip">주메뉴</h2>
# <div class="util_right_m">
# <ul class="no-login clearfix">
# <li><a href="httpS://www.foodsafetykorea.go.kr/portal/loginNew.do?menu_no=3817&amp;menu_grp=MENU_NEW07" title="로그인">로그인</a></li>
# <li><a href="httpS://www.foodsafetykorea.go.kr/portal/member/joinAgreeView.do" title="회원가입">회원가입</a></li>
# </ul>
# </div>
# <script type="text/javascript">
# 	$(document).ready(function() {
# 		var link = document.location.href;
# 		var menuTitle = "국내 제품";
# 		var menuLvl = "4";
# 		var parentMenuTitle = "건강기능식품검색";
# 		var pageTitle;
#
# 		if (link.indexOf('Detail.do') >= 0 || link.indexOf('detail.do') >=0){
# 			if($.trim(menuTitle).length <= 0){
# 				var txt = $('#sub_header').find('h3').text();
# 				if(txt.indexOf('rss') > 0){
# 					txt = txt.substr(0, txt.indexOf('rss'));
# 				}
# 				menuTitle = txt;
# 			}
# 			pageTitle = menuTitle + " - 상세" ;
# 		}else if(link.indexOf('boardWrite.do')>=0) {
# 			pageTitle = menuTitle + " - 작성";
# 		}else if(link.indexOf('login') >= 0) {
# 			pageTitle = "로그인";
# 		}else if(link.indexOf('searchSelect.do') >= 0){
# 			pageTitle = "통합검색";
# 		}else if(menuLvl == 4) {
# 			pageTitle = parentMenuTitle;
# 		}else{
# 			pageTitle = menuTitle;
# 		}
#
# 		if($.trim(pageTitle).length <= 0){
#
# 			var txt = $('#sub_header').find('h3').text();
# 			if(txt.indexOf('rss') > 0){
# 				txt = txt.substr(0, txt.indexOf('rss'));
# 			}
# 			pageTitle = txt;
# 		}
#
# 		$("#brwsTitle").text(pageTitle + " | 식품안전나라");
#
#
# 		if(link.indexOf('board') >= 0) {
# 			$('.excerpt').remove();
# 		}
# 	});
# </script>
# <div class="wrap" id="gnbMenu">
# <!-- depth1 -->
# <div class="depth depth1">
# <ul class="depth_list depth1_list cut">
# <li class="depth_item depth1_item n1">
# <a class="depth_text depth1_text" href="javascript://">식품 · 안전</a>
# <div class="depth depth2">
# <div class="depth2_content">
# <ul class="depth_list depth2_list cut">
# <li class="depth_item depth2_item">
# <a class="depth_text depth2_text" href="javascript://">식품안전</a>
# <ul class="depth depth3">
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW01&amp;menu_no=3120" target="_self">식품안전지식 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW01&amp;menu_no=3862" target="_self">생활속 식품통계이야기 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/termdictionary/termList.do?menu_grp=MENU_NEW01&amp;menu_no=4899" target="_self">용어사전 </a></li>
# </ul>
# </li>
# <li class="depth_item depth2_item">
# <a class="depth_text depth2_text" href="javascript://">건강기능식품</a>
# <ul class="depth depth3">
# <li><a class="depth_text depth3_text" href="/portal/healthyfoodlife/searchHomeHF.do?menu_grp=MENU_NEW01&amp;menu_no=2823" target="_self">건강기능식품검색 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW01&amp;menu_no=3811" target="_self">건강기능식품 정보 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/healthyfoodlife/functionality.do?menu_grp=MENU_NEW01&amp;menu_no=2657" target="_self">건강기능식품 기능별 정보 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW01&amp;menu_no=2660" target="_self">건강기능식품 원료별 정보 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW01&amp;menu_no=2664&amp;ctgryno=1155" target="_self">인허가/GMP </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW01&amp;menu_no=2675" target="_self">영업자지원 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW01&amp;menu_no=3702" target="_self">건강기능식품 섭취 주의사항 </a></li>
# </ul>
# </li>
# <li class="depth_item depth2_item">
# <a class="depth_text depth2_text" href="javascript://">수입식품</a>
# <ul class="depth depth3">
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW01&amp;menu_no=4444" target="_self">법령 및 제도 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW01&amp;menu_no=2611&amp;ctgType=CTG_TYPE01&amp;ctgryno=1138" target="_self">수입신고 및 검사 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW01&amp;menu_no=2616" target="_self">영업등록 방법 </a></li>
# <li><a class="depth_text depth3_text" href="https://impfood.mfds.go.kr/CFDAA01F01" target="_blank">수입식품통계 <img alt="새창열림" class="newwin" src="/images/2021/common_2021/newwindow_icon.png"/></a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW01&amp;menu_no=2640" target="_self">우수수입업소 </a></li>
# <li><a class="depth_text depth3_text" href="https://radsafe.mfds.go.kr" target="_blank">식품 중 방사능 정보 <img alt="새창열림" class="newwin" src="/images/2021/common_2021/newwindow_icon.png"/></a></li>
# </ul>
# </li>
# <li class="depth_item depth2_item">
# <a class="depth_text depth2_text" href="javascript://">식품첨가물/기구용기포장</a>
# <ul class="depth depth3">
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW01&amp;menu_no=3725" target="_self">식품첨가물이란? </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW01&amp;menu_no=3803" target="_self">기구등의 살균소독제란? </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW01&amp;menu_no=3802" target="_self">기구용기포장이란? </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW01&amp;menu_no=2694" target="_self">식품첨가물/기구용기포장 안전정보 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/safefoodlife/openSrchLmitStdrSrLedg.do?menu_no=3613&amp;menu_grp=MENU_NEW01" target="_self">식품첨가물 천연유래정보 </a></li>
# </ul>
# </li>
# <li class="depth_item depth2_item">
# <a class="depth_text depth2_text" href="javascript://">주류</a>
# <ul class="depth depth3">
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW01&amp;menu_no=4222" target="_self">주류 안전관리 정책 개요 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW01&amp;menu_no=2731" target="_self">주류 안전관리 정보 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW04&amp;menu_no=2719" target="_self">주류 법령 </a></li>
# </ul>
# </li>
# <li class="depth_item depth2_item">
# <a class="depth_text depth2_text" href="javascript://">식품표시 광고</a>
# <ul class="depth depth3">
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW01&amp;menu_no=3400" target="_self">식품표시광고 정보 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW01&amp;menu_no=3861" target="_self">표시ㆍ광고 자율심의 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW01&amp;menu_no=4106" target="_self">식품표시광고 FAQ </a></li>
# <li><a class="depth_text depth3_text" href="/portal/onlinesample/onlinesampleAgreeView.do" target="_self">식품 표시봇 (한글표시사항 견본) </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW01&amp;menu_no=4838&amp;ctgType=CTG_TYPE01&amp;ctgryno=2255" target="_self">식품등 부당한 표시•광고 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW01&amp;menu_no=4839" target="_self">적발사례 모음 </a></li>
# </ul>
# </li>
# <li class="depth_item depth2_item">
# <a class="depth_text depth2_text" href="javascript://">GMO</a>
# <ul class="depth depth3">
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW01&amp;menu_no=3800&amp;ctgType=CTG_TYPE01&amp;ctgryno=2222" target="_self">GMO의 이해 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/healthyfoodlife/examState.do?menu_grp=MENU_NEW01&amp;menu_no=3801" target="_self">GMO 안전성 심사 결과 보고서 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW01&amp;menu_no=2795" target="_self">GMO 표시 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW01&amp;menu_no=2812" target="_self">GMO 승인 현황 자료 </a></li>
# </ul>
# </li>
# <li class="depth_item depth2_item">
# <a class="depth_text depth2_text" href="javascript://">위생용품</a>
# <ul class="depth depth3">
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW01&amp;menu_no=3819" target="_self">위생용품법령 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW01&amp;menu_no=3701" target="_self">위생용품 안전관리 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW01&amp;menu_no=3820" target="_self">영업자 준수사항 </a></li>
# </ul>
# </li>
# <li class="depth_item depth2_item">
# <a class="depth_text depth2_text" href="javascript://">농축수산물안전정보</a>
# <ul class="depth depth3">
# <li><a class="depth_text depth3_text" href="/portal/fooddanger/farmInfoSearch.do?menu_grp=MENU_NEW01&amp;menu_no=4415" target="_self">달걀농장정보(산란계) </a></li>
# <li><a class="depth_text depth3_text" href="/portal/fooddanger/eggHazardList.do?menu_grp=MENU_NEW01&amp;menu_no=4416" target="_self">살충제 검출 계란 확인 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW01&amp;menu_no=4846" target="_self">수산물정보 </a></li>
# <li><a class="depth_text depth3_text" href="http://vibrio.foodsafetykorea.go.kr/main" target="_blank">비브리오패혈증균 예측시스템 <img alt="새창열림" class="newwin" src="/images/2021/common_2021/newwindow_icon.png"/></a></li>
# <li><a class="depth_text depth3_text" href="http://www.naqs.go.kr/jsp/falsdisp/violatorPublic4NAQS.jsp" target="_blank">농축산물 원산지표시위반 <img alt="새창열림" class="newwin" src="/images/2021/common_2021/newwindow_icon.png"/></a></li>
# <li><a class="depth_text depth3_text" href="https://www.nfqs.go.kr/hpmg/data/actionAnnounceViolatOriginForm.do?menuId=M0000232" target="_blank">수산물 원산지표시위반  <img alt="새창열림" class="newwin" src="/images/2021/common_2021/newwindow_icon.png"/></a></li>
# <li><a class="depth_text depth3_text" href="http://www.mfds.go.kr/brd/m_627/list.do" target="_blank">시험검사기관 지정현황 <img alt="새창열림" class="newwin" src="/images/2021/common_2021/newwindow_icon.png"/></a></li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="depth_item depth1_item n2">
# <a class="depth_text depth1_text" href="javascript://">위해 · 예방</a>
# <div class="depth depth2">
# <div class="depth2_content">
# <ul class="depth_list depth2_list cut">
# <li class="depth_item depth2_item">
# <a class="depth_text depth2_text" href="javascript://">위반식품 업체정보</a>
# <ul class="depth depth3">
# <li><a class="depth_text depth3_text" href="/portal/fooddanger/suspension.do?menu_no=2713&amp;menu_grp=MENU_NEW02" target="_self">회수•판매중지 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/fooddanger/testUnfitDom.do?menu_no=2710&amp;menu_grp=MENU_NEW02" target="_self">국내식품 부적합 </a></li>
# <li><a class="depth_text depth3_text" href="https://impfood.mfds.go.kr/CFCEE01F01" target="_blank">수입식품 부적합 <img alt="새창열림" class="newwin" src="/images/2021/common_2021/newwindow_icon.png"/></a></li>
# <li><a class="depth_text depth3_text" href="/portal/fooddanger/administMeasureList.do?menu_no=2714&amp;menu_grp=MENU_NEW02" target="_self">행정처분 </a></li>
# </ul>
# </li>
# <li class="depth_item depth2_item">
# <a class="depth_text depth2_text" href="javascript://">식중독정보</a>
# <ul class="depth depth3">
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW02&amp;menu_no=4418" target="_self">식중독이란? </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW02&amp;menu_no=4419" target="_self">식중독 예방법 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW02&amp;menu_no=4420" target="_self">식중독 발생시 대응 요령 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW02&amp;menu_no=4421" target="_self">식중독 예방 교육자료 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW02&amp;menu_no=4422" target="_self">식중독 예방 동영상 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW02&amp;menu_no=4423" target="_self">식중독 예방 홍보자료 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/specialinfo/poisonTeacherList.do?menu_grp=MENU_NEW02&amp;menu_no=3709" target="_self">식중독 예방강사 찾기 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/healthyfoodlife/foodPoisoningStat.do?menu_no=3724&amp;menu_grp=MENU_NEW02" target="_self">식중독 통계 </a></li>
# <li><a class="depth_text depth3_text" href="https://www.foodsafetykorea.go.kr/ews/user/loginForm.do" target="_blank">식중독조기경보시스템 <img alt="새창열림" class="newwin" src="/images/2021/common_2021/newwindow_icon.png"/></a></li>
# </ul>
# </li>
# <li class="depth_item depth2_item">
# <a class="depth_text depth2_text" href="javascript://">농약 허용물질목록 관리제도</a>
# <ul class="depth depth3">
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW02&amp;menu_no=4428" target="_self">농약PLS란 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW02&amp;menu_no=4236" target="_self">농약 잔류허용기준 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW02&amp;menu_no=4430" target="_self">수입식품 농약잔류허용기준 신청 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW02&amp;menu_no=3840" target="_self">자료실 </a></li>
# </ul>
# </li>
# <li class="depth_item depth2_item">
# <a class="depth_text depth2_text" href="javascript://">해외직구정보</a>
# <ul class="depth depth3">
# <li><a class="depth_text depth3_text" href="/portal/fooddanger/foodDirectImportView.do?menu_no=4901&amp;menu_grp=MENU_NEW01" target="_self">해외직구식품 올(ALL) 바로 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/fooddanger/foodDirectImportBlock.do?menu_grp=MENU_NEW02&amp;menu_no=3594" target="_self">위해식품 차단목록 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW02&amp;menu_no=3599" target="_self">해외 직구식품 안전정보 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW02&amp;menu_no=2806" target="_self">위해식품정보 </a></li>
# </ul>
# </li>
# <li class="depth_item depth2_item">
# <a class="depth_text depth2_text" href="javascript://">위생등급제</a>
# <ul class="depth depth3">
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW02&amp;menu_no=4433" target="_self">위생등급제 소개 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW02&amp;menu_no=3396" target="_self">관계법령 및 지정절차 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW02&amp;menu_no=4435" target="_self">위생등급제 신청서류 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/fooddanger/foodSafetyInfo/hgledgList.do?menu_grp=MENU_NEW02&amp;menu_no=3405" target="_self">위생등급제 지정현황 </a></li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="depth_item depth1_item n3">
# <a class="depth_text depth1_text" href="javascript://">건강 · 영양</a>
# <div class="depth depth2">
# <div class="depth2_content">
# <ul class="depth_list depth2_list cut">
# <li class="depth_item depth2_item">
# <a class="depth_text depth2_text" href="javascript://">식품영양정보</a>
# <ul class="depth depth3">
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW03&amp;menu_no=4847" target="_self">생애주기별 정보 </a></li>
# <li><a class="depth_text depth3_text" href="http://www.foodsafetykorea.go.kr/fcdb/" target="_blank">식품영양성분 DB <img alt="새창열림" class="newwin" src="/images/2021/common_2021/newwindow_icon.png"/></a></li>
# <li><a class="depth_text depth3_text" href="/portal/exhealthyfoodlife/index.html" target="_self">영양상담프로그램 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/healthyfoodlife/nutritionindex.do?menu_no=4849&amp;menu_grp=MENU_NEW03" target="_self">영양지수 </a></li>
# <li><a class="depth_text depth3_text" href="https://www.foodsafetykorea.go.kr/guide/" target="_blank">식품 안전 섭취가이드 프로그램 <img alt="새창열림" class="newwin" src="/images/2021/common_2021/newwindow_icon.png"/></a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW03&amp;menu_no=4837" target="_self">영양도서관 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW03&amp;menu_no=4852" target="_self">자료실 </a></li>
# </ul>
# </li>
# <li class="depth_item depth2_item">
# <a class="depth_text depth2_text" href="javascript://">어린이•청소년 식생활 안전관리</a>
# <ul class="depth depth3">
# <li><a class="depth_text depth3_text" href="http://www.foodsafetykorea.go.kr/hilow/index.do" target="_blank">어린이 기호식품 품질인증 <img alt="새창열림" class="newwin" src="/images/2021/common_2021/newwindow_icon.png"/></a></li>
# <li><a class="depth_text depth3_text" href="https://www.foodsafetykorea.go.kr/hilow/index.do" target="_blank">고열량 저영양 식품 <img alt="새창열림" class="newwin" src="/images/2021/common_2021/newwindow_icon.png"/></a></li>
# <li><a class="depth_text depth3_text" href="/portal/specialInfo/childFoodSafetyGuardArea.do?menu_grp=MENU_NEW03&amp;menu_no=3605" target="_self">어린이식품안전관리보호구역 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/specialinfo/childCenterList.do?menu_grp=MENU_NEW03&amp;menu_no=3604" target="_self">어린이급식관리지원센터 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/sensuousmenu/schoolMealsDetail.do?menu_grp=MENU_NEW03&amp;menu_no=3017" target="_self">우리학교 급식식단 </a></li>
# </ul>
# </li>
# <li class="depth_item depth2_item">
# <a class="depth_text depth2_text" href="javascript://">나트륨/당류 줄이기</a>
# <ul class="depth depth3">
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW03&amp;menu_no=2912" target="_self">나트륨 정보 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW03&amp;menu_no=2919" target="_self">당정보 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/cookrcp/cookRcpInfoList.do?rcp_cat=RC_COOK03&amp;menu_no=3608&amp;menu_grp=MENU_NEW03" target="_self">나트륨•당류 줄인 조리법 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/healthyfoodlife/naDownProgram.do?menu_grp=MENU_NEW03&amp;menu_no=2954" target="_self">미각 판정도구 </a></li>
# </ul>
# </li>
# <li class="depth_item depth2_item">
# <a class="depth_text depth2_text" href="javascript://">영양표시정보</a>
# <ul class="depth depth3">
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW03&amp;menu_no=3714" target="_self">가공식품 영양표시 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW03&amp;menu_no=3715" target="_self">조리식품 영양표시 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW03&amp;menu_no=4855&amp;ctgryno=2181" target="_self">외식 영양표시정보 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW03&amp;menu_no=3717" target="_self">자주하는 질문 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW03&amp;menu_no=3718" target="_self">교육/홍보자료 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/healthyfoodlife/myNutrientList.do?menu_grp=MENU_NEW03&amp;menu_no=2888" target="_self">영양성분표 산출 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW03&amp;menu_no=3720" target="_self">영양표시 교육 동영상 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW03&amp;menu_no=3719" target="_self">지침/해설서 </a></li>
# </ul>
# </li>
# <li class="depth_item depth2_item">
# <a class="depth_text depth2_text" href="javascript://">계산기</a>
# <ul class="depth depth3">
# <li><a class="depth_text depth3_text" href="/portal/healthyfoodlife/bmiCalcurator.do?menu_no=3071&amp;menu_grp=MENU_NEW03" target="_self">BMI 계산기 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/healthyfoodlife/workoutCalorie.do?menu_no=3073&amp;menu_grp=MENU_NEW03" target="_self">운동칼로리 계산기 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/healthyfoodlife/calorieDic.do?menu_no=3072&amp;menu_grp=MENU_NEW03" target="_self">칼로리사전 </a></li>
# <li><a class="depth_text depth3_text" href="http://www.foodsafetykorea.go.kr/mkisna/intro.do" target="_blank">칼로리코디 <img alt="새창열림" class="newwin" src="/images/2021/common_2021/newwindow_icon.png"/></a></li>
# <li><a class="depth_text depth3_text" href="/portal/healthyfoodlife/myNutrition.do?menu_grp=MENU_NEW03&amp;menu_no=4902" target="_self">나의 영양식단관리 </a></li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="depth_item depth1_item n4">
# <a class="depth_text depth1_text" href="javascript://">전문정보</a>
# <div class="depth depth2">
# <div class="depth2_content">
# <ul class="depth_list depth2_list cut">
# <li class="depth_item depth2_item">
# <a class="depth_text depth2_text" href="javascript://">업체제품검색</a>
# <ul class="depth depth3">
# <li><a class="depth_text depth3_text" href="/portal/specialinfo/searchInfoCompany.do?menu_grp=MENU_NEW04&amp;menu_no=2813" target="_self">업체 검색 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/specialinfo/searchInfoProduct.do?menu_grp=MENU_NEW04&amp;menu_no=2815" target="_self">국내식품 검색 </a></li>
# <li><a class="depth_text depth3_text" href="https://www.haccp.or.kr/site/haccp/masterForHACCP.do?key=2214" target="_blank">HACCP 인증 현황 <img alt="새창열림" class="newwin" src="/images/2021/common_2021/newwindow_icon.png"/></a></li>
# <li><a class="depth_text depth3_text" href="https://impfood.mfds.go.kr/CFCCC01F01" target="_blank">수입식품 검색 <img alt="새창열림" class="newwin" src="/images/2021/common_2021/newwindow_icon.png"/></a></li>
# <li><a class="depth_text depth3_text" href="/portal/safefoodlife/foodTraceability/foodTraceability.do?menu_grp=MENU_NEW04&amp;menu_no=2819" target="_self">이력정보 조회 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/fooddanger/foodSafetyInfo.do?menu_no=2828&amp;menu_grp=MENU_NEW04" target="_self">우리동네 식품안전정보 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/safefoodlife/foodImport/importFreezing/importFreezing.do?menu_grp=MENU_NEW04&amp;menu_no=2641" target="_self">수입쇠고기 냉동전환 확인 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/specialinfo/foodTruckList.do?menu_grp=MENU_NEW04&amp;menu_no=2986" target="_self">푸드트럭 </a></li>
# </ul>
# </li>
# <li class="depth_item depth2_item">
# <a class="depth_text depth2_text" href="javascript://">영업자 지원정보</a>
# <ul class="depth depth3">
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW04&amp;menu_no=3504" target="_self">영업자 4대 준수사항 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/specialinfo/examFeeList.do?menu_grp=MENU_NEW04&amp;menu_no=3500" target="_self">검사기관별 시험항목 검색 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/specialinfo/overseasFoodSafetyInfo.do?menu_grp=MENU_NEW04&amp;menu_no=3513" target="_self">해외식품 안전정보 사이트 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/specialinfo/workFlow.do?menu_grp=MENU_NEW04&amp;menu_no=2602" target="_self">식품 행정 업무 안내 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW04&amp;menu_no=3116" target="_self">수출식품 지원정보 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW04&amp;menu_no=2603" target="_self">국가 식품안전 관리체계 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/specialinfo/myFoodType.do?menu_grp=MENU_NEW04&amp;menu_no=2971" target="_self">유통기한 설정 </a></li>
# </ul>
# </li>
# <li class="depth_item depth2_item">
# <a class="depth_text depth2_text" href="javascript://">법령정보</a>
# <ul class="depth depth3">
# <li><a class="depth_text depth3_text" href="/portal/specialinfo/infoMapLaw.do?menu_grp=MENU_NEW04&amp;menu_no=2846" target="_self">식품안전 법령 정보맵 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/specialinfo/infoMapCodex.do?menu_grp=MENU_NEW04&amp;menu_no=2848" target="_self">식품안전 기준규격 정보맵 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/specialinfo/infoMapStat.do?menu_grp=MENU_NEW04&amp;menu_no=2850" target="_self">식품안전 통계 정보맵 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW04&amp;menu_no=4108" target="_self">법령 유권해석(FAQ) </a></li>
# <li><a class="depth_text depth3_text" href="https://www.mfds.go.kr/law/main.do" target="_blank">식의약 법령정보 <img alt="새창열림" class="newwin" src="/images/2021/common_2021/newwindow_icon.png"/></a></li>
# </ul>
# </li>
# <li class="depth_item depth2_item">
# <a class="depth_text depth2_text" href="javascript://">기준규격정보</a>
# <ul class="depth depth3">
# <li><a class="depth_text depth3_text" href="https://foodsafetykorea.go.kr/foodcode/01_01.jsp" target="_blank">공전 <img alt="새창열림" class="newwin" src="/images/2021/common_2021/newwindow_icon.png"/></a></li>
# <li><a class="depth_text depth3_text" href="/portal/safefoodlife/notification.do?ntfc_dvs=NTFC01&amp;menu_grp=MENU_NEW04&amp;menu_no=3102" target="_self">기준규격개정고시 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/safefoodlife/notification.do?ntfc_dvs=NTFC04&amp;menu_grp=MENU_NEW04&amp;menu_no=4893" target="_self">한시적 기준규격 인정기준 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW04&amp;menu_no=3501" target="_self">식품 등 기준/규격 개선협의체 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW04&amp;menu_no=4854" target="_self">권장규격 초과제품 </a></li>
# </ul>
# </li>
# <li class="depth_item depth2_item">
# <a class="depth_text depth2_text" href="javascript://">식품원료</a>
# <ul class="depth depth3">
# <li><a class="depth_text depth3_text" href="/portal/safefoodlife/foodMeterial/foodMeterialDB.do?menu_no=2968&amp;menu_grp=MENU_NEW04" target="_self">식품원료목록 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW04&amp;menu_no=2948" target="_self">식품원료 관리 및 이해 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW04&amp;menu_no=2966" target="_self">식품원료한시적인정 </a></li>
# </ul>
# </li>
# <li class="depth_item depth2_item">
# <a class="depth_text depth2_text" href="javascript://">잔류·유해물질 정보</a>
# <ul class="depth depth3">
# <li><a class="depth_text depth3_text" href="http://www.foodsafetykorea.go.kr/residue/main.do" target="_blank">잔류물질 정보 <img alt="새창열림" class="newwin" src="/images/2021/common_2021/newwindow_icon.png"/></a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW04&amp;menu_no=2944" target="_self">유해물질 정보 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW04&amp;menu_no=3996" target="_self">오염물질 정보 </a></li>
# </ul>
# </li>
# <li class="depth_item depth2_item">
# <a class="depth_text depth2_text" href="javascript://">CODEX 정보</a>
# <ul class="depth depth3">
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW04&amp;menu_no=2909&amp;ctgryno=1823" target="_self">CODEX 소개 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW04&amp;menu_no=3519" target="_self">CODEX 활동 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/specialinfo/codexStandardList.do?data_type=STAN&amp;menu_grp=MENU_NEW04&amp;menu_no=2927" target="_self">CODEX 관련 규정 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW04&amp;menu_no=2936" target="_self">CODEX 자료실 </a></li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="depth_item depth1_item n5">
# <a class="depth_text depth1_text" href="javascript://">알림 · 교육</a>
# <div class="depth depth2">
# <div class="depth2_content">
# <ul class="depth_list depth2_list cut">
# <li class="depth_item depth2_item">
# <a class="depth_text depth2_text" href="javascript://">이슈</a>
# <ul class="depth depth3">
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW05&amp;menu_no=8083" target="_self">핫픽 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/issue/hotIssueList.do?menu_grp=MENU_NEW05&amp;menu_no=2832" target="_self">핫이슈 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW05&amp;menu_no=3409" target="_self">식품 안전이슈 20가지 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW05&amp;menu_no=4447" target="_self">이벤트 </a></li>
# </ul>
# </li>
# <li class="depth_item depth2_item">
# <a class="depth_text depth2_text" href="javascript://">식품안전뉴스</a>
# <ul class="depth depth3">
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW05&amp;menu_no=2859" target="_self">국내뉴스 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW05&amp;menu_no=2857" target="_self">보도참고자료 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW05&amp;menu_no=2854" target="_self">포토뉴스 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW05&amp;menu_no=4122" target="_self">해외뉴스 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW05&amp;menu_no=2852" target="_self">정책소식 </a></li>
# </ul>
# </li>
# <li class="depth_item depth2_item">
# <a class="depth_text depth2_text" href="javascript://">교육홍보자료실</a>
# <ul class="depth depth3">
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW05&amp;menu_no=2873" target="_self">홍보자료 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW05&amp;menu_no=2880" target="_self">교육자료 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW05&amp;menu_no=2882" target="_self">영상자료 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/sympathyplus/infographic.do?menu_grp=MENU_NEW05&amp;menu_no=2892" target="_self">인포그래픽 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/webtoon/openWebToonTotLst.do?menu_grp=MENU_NEW05&amp;menu_no=3401" target="_self">웹툰 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW05&amp;menu_no=3818" target="_self">식품안전나라 서포터즈 </a></li>
# </ul>
# </li>
# <li class="depth_item depth2_item">
# <a class="depth_text depth2_text" href="javascript://">간행물자료실</a>
# <ul class="depth depth3">
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW05&amp;menu_no=2887" target="_self">웹진(매거진F/열린마루) </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW05&amp;menu_no=3852" target="_self">뉴스레터 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW05&amp;menu_no=2890" target="_self">열린포럼 </a></li>
# </ul>
# </li>
# <li class="depth_item depth2_item">
# <a class="depth_text depth2_text" href="javascript://">이용안내</a>
# <ul class="depth depth3">
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW06&amp;menu_no=4904" target="_self">공지사항 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW05&amp;menu_no=4910" target="_self">포탈이용관련 질의응답 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW05&amp;menu_no=4909" target="_self">자주하는 질문 </a></li>
# <li><a class="depth_text depth3_text" href="/portal/board/board.do?menu_grp=MENU_NEW05&amp;menu_no=4907" target="_self">정보오류 신고 </a></li>
# </ul>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="depth_item depth1_item n6 mobile_item">
# <a class="depth_text depth1_text" href="javascript://">전자민원</a>
# <div class="depth depth2">
# <div class="depth2_content">
# <ul class="depth_list depth2_list cut">
# <li class="depth_item depth2_item">
# <a class="depth_text depth2_text" href="/portalmobile/minwonMoMain.do?menu_no=4896&amp;menu_grp=MENU_MOB02">전자민원</a>
# </li>
# <li class="depth_item depth2_item">
# <a class="depth_text depth2_text" href="/portal/consumerNotify/customerNotifyStep1.do?rcptDvs=I&amp;mobileFlag=1&amp;menu_no=4897&amp;menu_grp=MENU_MOB03">1399 소비자신고</a>
# </li>
# <li class="depth_item depth2_item">
# <a class="depth_text depth2_text" href="/portal/company/selfInfoList.do?menu_no=4895&amp;menu_grp=MENU_MOB01">자율점검보고서</a>
# </li>
# <li class="depth_item depth2_item">
# <a class="depth_text depth2_text" href="/portal/selfCheck/offFlavorSelfList.do?menu_no=4898&amp;menu_grp=MENU_MOB04">이취(이미) 자율점검보고서</a>
# </li>
# </ul>
# </div>
# </div>
# </li>
# <li class="depth_item depth1_item mobile_item data">
# <a class="depth_text depth1_text" href="/apiMain.do" target="_self">공공데이터</a>
# </li>
# </ul>
# </div>
# <!-- // depth1 -->
# </div>
# <div class="menu_hide">
# <button class="menu_btn" type="button">주메뉴 닫기</button>
# </div>
# </nav>
# <a class="gnb_close" href="javascript://">닫기</a>
# </div>
# <div class="total_menu">
# <a class="gnb_btn gnb_btn_bg1" href="javascript://" title="레이어열기">전체메뉴</a>
# </div>
# </header>
# <head>
# <script>
#         /* gog_2021 고도화 반응형 웹 개편 - 메뉴 실명제 기능 재사용 */
#         $(document).ready(function () {
#             menuAdminInfo(2823);
#
#             $(".zipcode,.maker,.vendor").fancybox({
#                 maxWidth: 800,
#                 maxHeight: 760,
#                 minHeight: 760,
#                 fitToView: false,
#                 width: '70%',
#                 height: '80%',
#                 autoSize: false,
#                 closeClick: false,
#                 openEffect: 'fade',
#                 closeEffect: 'fade',
#                 tpl: {next: '', prev: ''},
#                 padding: 0,
#                 helpers: {overlay: {locked: false}}
#             });
#
#             $(".foodtype,.origin,.organization").fancybox({
#                 maxWidth: 650,
#                 maxHeight: 600,
#                 minHeight: 600,
#                 fitToView: false,
#                 width: '70%',
#                 height: '80%',
#                 autoSize: false,
#                 closeClick: false,
#                 openEffect: 'fade',
#                 closeEffect: 'fade',
#                 padding: 0,
#                 tpl: {next: '', prev: ''},
#                 helpers: {overlay: {locked: false}}
#             });
#
#             //레이어팝업 셋팅
#             $(".fileUpload").fancybox({
#                 maxWidth: 530,
#                 maxHeight: 450,
#                 minHeight: 100,
#                 fitToView: false,
#                 width: '70%',
#                 height: '45%',
#                 autoSize: false,
#                 closeClick: false,
#                 openEffect: 'fade',
#                 closeEffect: 'fade',
#                 //tpl: {next : '', prev : ''},
#                 padding: 0,
#                 helpers: {overlay: {locked: false}}
#             });
#
#             $(".addr").fancybox({
#                 maxWidth: 840,
#                 maxHeight: 760,
#                 minHeight: 760,
#                 fitToView: false,
#                 width: '100%',
#                 height: '100%',
#                 autoSize: false,
#                 closeClick: false,
#                 openEffect: 'fade',
#                 closeEffect: 'fade',
#                 tpl: {next: '', prev: ''},
#                 padding: 0,
#                 helpers: {overlay: {locked: true}}
#             });
#         });
#
#         //메뉴 실명제 2020_djlee
#         function menuAdminInfo(menu_no) {
#             if (menu_no === undefined) {
#                 return;
#             }
#             $.ajax({
#                 data: {menu_no: menu_no},
#                 dataType: 'json',
#                 type: 'POST',
#                 async: false,
#                 url: "" + "/portal/menuAdminInfo.do",
#                 success: function (data) {
#                     printAdminInfo(data.menuAdminVO);
#                 },
#                 error: function (request, status, error) {
#                 }
#             });
#         }
#
#         //메뉴 실명제 2020 djlee
#         function printAdminInfo(info) {
#             //console.log(info);
#             var elem, parent;
#             var adminInfo = '';
#             if (info === undefined) {
#                 return;
#             }
# //		alert(info.menu_no);
# //     	if (true) {
#
#             var menuAdminArea = $('.menu-admin');
#             if (menuAdminArea.length <= 0) {
#                 if (info.psitn_dept !== undefined && info.psitn_dept.length > 0) {
#                     elem = document.createElement("div");
#                     elem.setAttribute("class", 'menu-admin');
#                     adminInfo += '<div class="box03 p-box">';
#                     if (info.menu_no == '2713' || info.menu_no == '2710') {
#                         adminInfo += '<span class="p-icon"><h>식품관리총괄과(043-719-2071) / 건강기능식품정책과(2460) / 농수산물안전정책과(3202, 3217) / 축산물안전정책과(3257) / 수입유통안전과(6258)</h></span>';
#                     } else {
#                         if (info.psitn_dept != undefined && info.psitn_dept != '') {
#                             adminInfo += '<span class="p-icon"><b>담당부서</b><h>' + info.psitn_dept + '</h></span>';
#                         }
#                         if (info.tel_no != undefined && info.tel_no != '') {
#                             adminInfo += '<span class="p-icon1"><b>연락처</b><h>' + info.tel_no + '</h></span>';
#                         }
#                     }
#                     adminInfo += '</div>';
#                     elem.innerHTML = adminInfo;
#                     parent = document.querySelector("main article article");
#                     if (parent) {
#                         //console.log(1);
#                         //console.log(parent);
#                         parent.appendChild(elem);
#                     } else {
#                         parent = document.querySelector("main article");
#                         if (parent) {
#
#                             var articleCnt = $('#popRecArea').find('article').length;
#                             if (articleCnt > 1) {
#                                 $('#popRecArea').find('article').each(function () {
#                                     $(this).append(elem);
#                                 });
#                             } else {
#                                 parent.appendChild(elem);
#                             }
#                         } else {
#                             parent = document.querySelector('div#content-wrap');
#                             if (parent) {
#                                 //console.log(4);
#                                 //console.log(parent);
#                                 parent.appendChild(elem);
#                             } else {
#                                 parent = document.querySelector('main[role="main"]');
#                                 if (parent) {
#                                     //console.log(5);
#                                     //console.log(parent);
#                                     parent.appendChild(elem);
#                                 }
#                             }
#                         }
#                     }
#                 }
#             } else {
#                 if (info.menu_no == '2611') { // 수입신고 및 검사용
#                     if (info.psitn_dept !== undefined && info.psitn_dept.length > 0) {
#                         elem = document.createElement("div");
#                         elem.setAttribute("class", 'menu-admin');
#                         adminInfo += '<div class="box03 p-box">';
#                         if (info.menu_no == '2713' || info.menu_no == '2710') {
#                             adminInfo += '<span class="p-icon"><h>식품관리총괄과(043-719-2071) / 건강기능식품정책과(2460) / 농수산물안전정책과(3202, 3217) / 축산물안전정책과(3257) / 수입유통안전과(6258)</h></span>';
#                         } else {
#                             if (info.psitn_dept != undefined && info.psitn_dept != '') {
#                                 adminInfo += '<span class="p-icon"><b>담당부서</b><h>' + info.psitn_dept + '</h></span>';
#                             }
#                             if (info.tel_no != undefined && info.tel_no != '') {
#                                 adminInfo += '<span class="p-icon1"><b>연락처</b><h>' + info.tel_no + '</h></span>';
#                             }
#                         }
#                         adminInfo += '</div>';
# ...
# <input id="show_cnt" name="show_cnt" type="hidden" value="10"/> <!-- show_cnt -->
# <script id="searchList" type="text/html">
# 	<tr>
# 		<td class="num">{no}</td>
# 		<td style="cursor: pointer; text-align: left;">{prdlst_nm}</td>
# 		<td style="cursor: pointer; text-align: left;">{bssh_nm}</td>
# 		<td class="num" style="cursor: pointer;">{prdlst_report_no}</td>
# 		<td class="num">{prms_dt}</td>
# 		<input type="hidden" value="{prdlst_report_ledg_no}" />
# 	</tr>
# </script>
# <script>
# /***************************************************************************************
# * 시스템명 	: 식품의약품안전처 통합식품안전망구축
# * 업무명 		: 건강기능식품 - 국내 검색
# * 파일명 		: searchHomeHF.jsp
# * 작성자 		: 장영철
# * 작성일 		: 2014.12.04
# *
# * 설  명		: 건강기능식품 - 국내 검색
# *------------------------------------------------------------------------------------
# * 변경일	변경자		변경내역
# *------------------------------------------------------------------------------------
# *  2014.12.04 장영철		최초 프로그램 작성
# *
# *------------------------------------------------------------------------------------
# **************************************************************************************/
#
# /**************************************************************************************
# * Variable
# **************************************************************************************/
# var total_cnt_onPage = 0;
# var show_cnt_onPage = 10;
# var search_code = '';
#
# /**************************************************************************************
# * Init & Event
# **************************************************************************************/
# $(function() {
# 	//페이징
# 	$('.pagination').pagination({items: total_cnt_onPage, itemsOnPage: show_cnt_onPage, cssStyle: 'compact-theme'});
#
# 	//페이지 클릭시
# 	$('.pagination').click(function(){
#         var page = $('.pagination').pagination('getCurrentPage');
#
#         if($('#start_idx').val() != page){
#             $('#start_idx').val(page);
#             fn_search('page');
#         }
#         return false;
#     });
#
# 	//검색
# 	$('.btn.btn-default').click(function(){
# 		fn_search();
# 	});
#
# 	//검색 enter
# 	$('#search_word').bind('keydown', function(e) {
#         if (e.keyCode == 13) {
#         	fn_search();
#         }
#     });
#
# 	//디테일에서 리스트보기용
# 	if(nvl(search_code) != ''){
# 		$('#search_code').val(search_code);
# 		$('#search_code').selecter('update');
# 	}
#
# 	fn_searchList();
#
# });
#
# /**************************************************************************************
# * Function
# **************************************************************************************/
#
# //페이징 변수셋팅
# function fn_setPaginationVars(){
#  	show_cnt_onPage = $('#show_cnt').val();
#
#  	$('.pagination').pagination("updateItems", total_cnt_onPage);
#  	$('.pagination').pagination("updateItemsOnPage", show_cnt_onPage);
#
#  	var pageNum = $('#start_idx').val();
#
#  	if(pageNum == null || pageNum == ''){
#  		pageNum = 1;
#  	}
#
#  	$('.pagination').pagination('drawPage', pageNum);
# }
#
# //검색
# function fn_search(flag){
# 	fn_replace('#search_word');		//trim
# 	fn_replaceSpecialChar('#search_word');		//특수문자 제거
#
# 	if(flag != 'page')
# 		$('#start_idx').val('1');
#
# 	fn_searchList();
# }
#
# //상세 화면으로 이동
# function fn_moveDetail(prdlstReportLedgNo){
# 	var form = $('<form/>', {method: 'POST', action: '/portal/healthyfoodlife/searchHomeHFDetail.do'});
# 	form.append($('<input/>', {type: 'hidden', name: 'prdlstReportLedgNo', value: prdlstReportLedgNo}));
# 	form.append($('<input/>', {type: 'hidden', name: 'search_word', value: $('#search_word').val()}));
# 	form.append($('<input/>', {type: 'hidden', name: 'search_code', value: $('#search_code').val()}));
# 	form.append($('<input/>', {type: 'hidden', name: 'start_idx', value: $('.pagination').pagination('getCurrentPage')}));
# // 	form.append($('<input/>', {type: 'hidden', name: 'menu_no', value: '914'}));
# // 	form.append($('<input/>', {type: 'hidden', name: 'menu_grp', value: 'MENU_GRP02'}));
# 	form.append($('<input/>', {type: 'hidden', name: 'menu_no', value: '2823'}));			//선진화 새 메뉴번호로 수정		2017.01.26 Park
# 	form.append($('<input/>', {type: 'hidden', name: 'menu_grp', value: 'MENU_NEW01'}));	//선진화 새 메뉴그룹으로 수정	2017.01.26 Park
# 	$(document.body).append(form);
#
# 	form.submit();
# }
#
# /**************************************************************************************
# * Ajax
# **************************************************************************************/
# //품목정보를 가져온다.
# function fn_searchList(){
# 	$.ajax({
# 		data: $('#baseForm').serialize(),
#  		dataType: 'json',
#  		type: 'POST',
#  		url: '/portal/healthyfoodlife/searchHomeHFProc.do'
#  	}).done(function(rstData){
#  		var data;
#   		var strHtml = '';
#
#   		if(rstData != null && rstData.length > 0){
#   			total_cnt_onPage = rstData[0].total_count;
#
#  			$.each(rstData, function(idx) {
#  				data = null;
#  				data = {
#  						no: (total_cnt_onPage - this['no'])+1,
#  						prdlst_nm: nvl(this['prdlst_nm']),
#  						bssh_nm: nvl(this['bssh_nm']),
#  						prdlst_report_no: nvl(this['prdlst_report_no']),
#  						prms_dt: formatDate(this['prms_dt'], '-'),
#  						prdlst_report_ledg_no: nvl(this['prdlst_report_ledg_no'])
#  	  			};
#  				strHtml += innerHtmlMaker('#searchList', data);
#  	 		});
#
#  		}else{
#  			total_cnt_onPage = 0;
#  		}
#
#   		$('tbody').html(strHtml);
#  		$('.total').html('Total: <strong>'+ fn_addComma(total_cnt_onPage) + ' Products</strong>');
#  		fn_setPaginationVars();
#
#  		$('tbody > tr').click(function(){
#  			fn_moveDetail($(this).find('input').val());
#  		});
#
#  	}).fail(function(request ,status, error){
#  		alert('시스템에러가 발생하였습니다. 관리자에게 문의하십시오.');
#  	});
# }
# </script>
# </main>
# </div>
# <!-- chatbot_icon -->
# <div class="sub_chatbot_wrap">
# <div class="GreetingWrapper">
# <div class="greeting-content">
# <div class="greeting-img"></div>
# <div class="greeting-texts">
# 				안녕하세요. <strong>식품안전나라 메뉴 안내봇에</strong>
# <p>오신 걸 환영합니다!</p>
# </div>
# </div>
# <button class="btn-close" id="btnGreetingClose"></button>
# </div>
# <div class="sub_chatbot_icon">
# <a class="chatbot_open" href="javascript://" onclick="popupCenter('http://foodsafety.wisenut.kr:17400/fskorea/', 500, 700)" title="챗봇 새창열기">챗봇열기</a>
# <a class="chatbot_icon_close" href="javascript:;">챗봇아이콘닫기</a>
# </div>
# </div>
# <!-- // chatbot_icon -->
# <!-- footer  -->
# <footer id="footer">
# <!-- 하단메뉴  -->
# <div id="fnb">
# <div class="container-fluid clearfix">
# <h2 class="hid">하단메뉴</h2>
# <ul class="nav">
# <li><a href="http://www.mfds.go.kr/wpge/m_30/de010802l001.do" target="_blank" title="개인정보처리방침 사이트로 이동합니다.">개인정보처리방침</a></li>
# <li><a href="http://www.mfds.go.kr/wpge/m_34/de010802l001.do" target="_blank" title="저작권정책 사이트로 이동합니다.">저작권정책</a></li>
# <li><a href="/portal/board/board.do?menu_no=2938&amp;menu_grp=MENU_NEW07" title="관련사이트 페이지로 이동합니다.">관련사이트</a></li>
# <li><a href="/minwon/counsel/ePeople.do" title="국민신문고 페이지로 이동합니다.">국민신문고</a></li>
# <li><a href="/portal/board/board.do?menu_no=4004&amp;menu_grp=MENU_NEW07">RSS서비스</a></li>
# <li><a href="http://113366.com/foodinfo" target="_blank" title="원격지원서비스 사이트로 이동합니다."><strong>원격지원서비스</strong></a></li>
# </ul>
# <ul class="sns">
# <li><a href="https://www.facebook.com/365daysfoodsafety/" target="_blank" title="식품안전나라 페이스북 페이지로 이동합니다.">페이스북</a></li>
# <li><a href="https://twitter.com/365foodsafety" target="_blank" title="식품안전나라 트위터 페이지로 이동합니다.">트위터</a></li>
# <li><a href="https://post.naver.com/mfds5590" target="_blank" title="식품안전나라 유튜브 페이지로 이동합니다.">유튜브</a></li>
# <li><a href="https://pf.kakao.com/_xnGxkWC?from=qr" target="_blank" title="식품안전나라 트위터 페이지로 이동합니다.림">트위터</a></li>
# <li><a href="https://www.instagram.com/foodsafetykorea/" target="_blank" title="식품안전나라 인스타그램 페이지로 이동합니다.">인스타그램</a></li>
# </ul>
# </div>
# </div>
# <!-- //하단메뉴  -->
# <div class="siteinfo">
# <div class="container-fluid">
# <div class="fL">
# <div class="address-copyr">
# <address class="address">
# 						우)28159 충청북도 청주시 흥덕구 오송읍 오송생명2로 187 오송보건의료행정타운 식품의약품안전처
# 					</address>
# <p class="copyr">Copyright ⓒ Ministry of Food and Drug Safety. All Rights Reserved.</p>
# <p class="copyr">통합망 고객지원센터 : 1899-5590, 식약처 종합상담센터: 1577-1255</p>
# </div>
# </div>
# <div class="gov-share">
# <ul class="share">
# <li><img alt="식품의약품 안전처" src="/images/2021/common_2021/mfds_logo.jpg" style="margin-top:-7px;"/></li>
# <li><img alt="식품안전정보원" src="/images/2021/common_2021/foodinfo_logo.png"/></li>
# <li><img src="/images/2021/common_2021/footer_certi1.png" title="국가대표브랜드"/></li>
# </ul>
# </div>
# <div class="clearfix"></div>
# </div>
# </div>
# </footer>
# <!-- //footer  -->
# </div>
# </input></input></input></input></form>
# </div>
# <script>
# 	$(document).ready(function() {
# 		//인기검색어 추출
# 		fn_favoriteKWD();
#
# 	    fn_selectFavorMenu();
#
# 	    fn_selectSearchDetailTerm();
#
# 		//gog추가 - 즐겨찾기 등록 로직
# 		$("#favoriteStar").click(function () {
# 			if($("#mberId").val() == ""){
# 				alert("로그인 후 사용가능합니다.");
# 				return false;
# 			}
#
# 			if($("#favorRegYn").val() == "Y"){
# 				alert("이미 즐겨찾기 메뉴목록에 추가되어있는 메뉴 입니다.");
# 				return false;
# 			}
#
# 			if($("#favorListCnt").val() >= 8){
# 				alert("즐겨찾기 메뉴는 8개이상을 추가하실 수 없습니다.");
# 				return false;
# 			}
#
# 			var confirmResult = confirm($("#menuNm").val() + " 메뉴를 즐겨찾기 목록에 추가하시겠습니까?");
# 			if(confirmResult){
# 				$.ajax({
# 					data: $('#baseForm').serialize(),
# 					dataType:'json',
# 					type:'POST',
# 					url:"/ajax/postFavoriteMenu.do",
# 					success:function(arg){
# 						if(arg.result == 1) {
# 							alert($("#menuNm").val() + " 메뉴가 즐겨찾기 메뉴에 추가되었습니다.");
# 							fn_selectFavorMenu(); //목록 재호출
# 						}else{
# 							alert("즐겨찾기 추가에 실패하였습니다. 관리자에게 문의하세요.");
# 						}
# 					},
# 					error:function(request,status,error){
# 						alert('시스템에러가 발생하였습니다. 관리자에게 문의하십시오.');
# 					}
# 				});
# 			}
# 		});
#
#
# 		//마우스 다른구역 클릭시 정렬 Tab 제거
# 		$(document).mousedown(function(e) {
# 			//사이트맵
# 			if(!$(".sitemap_op,.sitemap").has(e.target).length)	{
# 				$(".sitemap_op,.sitemap").hide();
# 			}
#
# 		});
#
# 	});
#
#
# 	//인기검색어 추출
# 	function fn_favoriteKWD()	{
# 		$.ajax({
# 			dataType:'json',
# 			type:'POST',
# 			global: false,
# 			url:'/portal/main/selectFavoriteKWD.do',
# 			success:function(data){
# 				var list = data.listTrend;
# 				var htmlStr = "";
# 				var rank = 1;
# 				if(list != null) {
# 					for(var i=0;i<list.length;i++)	{
# 						htmlStr += "<li> ";
# 						htmlStr += "<a href=\"javascript:fn_searchTranTop('"+list[i]["KEYWORD"]+"');\"><span>"+rank+". </span>"+list[i]["KEYWORD"]+"</a>";
# 						htmlStr += " </li>";
# 						rank++;
# 					}
# 				}
# 				$("#listTrand").html(htmlStr);
# 			}
# 		});
# 	}
#
# 	function fn_selectFavorMenu(){
# 		// gog 추가 - 서브 페이지 로드시 마다 즐겨찾기 내역 조회
# 		$.ajax({
# 			data: $('#baseForm').serialize(), //portalLayout의 히든값 전체를 전송
# 			dataType:'json',
# 			type:'POST',
# 			url:"/ajax/getRegiedFavoriteMenu.do",
# 			success:function(data){
# 				if(data != null && data != "undefined") {
# 					var cnt = data.favorMenuList.length;
# 					$("#menuNm").val(data.pageNm); //현재 메뉴명 저장
# 					$("#favorListCnt").val(cnt); //리스트갯수저장
# 					$(".bookmark_list div ul").empty(); //하위태그를 그리기위해 비우기
# 					//현행 구조상 중복 리스트를 넣어둘 공간이 없으므로 이곳에서 즐겨찾기 중복페이지인지 먼저 체크하도록 함
# 					if(cnt === 0){
# 						$(".bookmark_list div ul").append("<span style='display:block; text-align:center; font-size:13px; color:#656363; margin-top:30px;'>즐겨찾기 메뉴가 없습니다.<br>즐겨찾기에 메뉴를 추가하시려면 각 메뉴별<br>상단에 위치한 별모양 아이콘을 눌러주세요.</span><div class='bookmark_ct'>자주찾는 메뉴를 추가해주세요</div>");
# 					}else{
# 						for(var i = 0 ; i < cnt ; i++) {
# 							$(".bookmark_list div ul").append("<li><a href="+data.favorMenuList[i].url+"></a><button type='button' class='bookmark_del_btn' onclick='fn_removeFavorMenu(, "+data.favorMenuList[i].seq+", \""+data.favorMenuList[i].menuNm+"\")'></button></li>");
# 							$(".bookmark_list div a").eq(i).text(data.favorMenuList[i].menuNm);
#
# 							if (data.favorMenuList[i].menuNo == $("#menu_no").val()) {
# 								$("#favorRegYn").val("Y");
# 							}
# 						}
# 					}
# 				}
# 			},
# 			error:function(request,status,error){
# 				alert('시스템에러가 발생하였습니다. 관리자에게 문의하십시오.');
# 			}
# 		});
# 	}
#
# 	//즐겨찾기 삭제
# 	function fn_removeFavorMenu(mberNo, seq, menuNm){
# 		var confirmResult = confirm(menuNm + " 메뉴를 즐겨찾기 목록에서 삭제하시겠습니까?");
# 		if(confirmResult){
# 			$.ajax({
# 				data: {mberNo : mberNo, seq : seq},
# 				dataType:'json',
# 				type:'POST',
# 				url:"/ajax/deleteFavoriteMenu.do",
# 				success:function(arg){
# 					if(arg.result == 1) {
# 						alert(menuNm + " 메뉴가 즐겨찾기에서 삭제되었습니다.");
# 						$("#favorRegYn").val("N"); // 추가여부 N으로 다시 변경
# 						fn_selectFavorMenu(); //목록 재호출
# 					}else{
# 						alert("즐겨찾기 메뉴 삭제에 실패하였습니다. 관리자에게 문의해주세요.");
# 					}
# 				},
# 				error:function(request,status,error){
# 					alert('시스템에러가 발생하였습니다. 관리자에게 문의하십시오.');
# 				}
# 			});
# 		}
# 	}
#
#
# 	//비브리오패혈증균 클릭시
# 	function openLink(){
# 		window.open("/vibrio/main","비브리오패혈증균 예측시스템","width=1350px,height=920px, directories=no, resizable=yes, scrollbars=no, location=no, menubar=no, toolbar=no, status=no, left=0");
# 	}
#
# 	function fn_skip(){
# 		return;
# 	}
#
# 	//통합검색 페이지이동
# 	function fn_searchTop() {
# 		var term = $('#pc_searchTopTerm').val();
# 		if(!term){
# 			term = $('#mob_searchTopTerm').val();
# 		}
#
# 		//gog_2021고도화 반응형 웹 개선 - 웹,모바일 모두 통합검색이 있어 값은 name을 통해 가져옴
# 		if($.trim(term).length > 0){
# 			$('#searchMode1_searchForm').val("search");
# 			$('#currentPage_searchForm').val("1");
# 			$("#colTarget_searchForm").val("total");
# 			$("#headerCheck_searchForm").val("Y");
# 			$('#reSearch_searchForm').val("");
# 			$("#menu_no_searchForm").val("3090");
# 			$("#menu_grp_searchForm").val("MENU_NEW07");
# 			setSearchCookie(term);
# 			document.searchForm.action="/portal/search/searchSelect.do";
# 			document.searchForm.target="_self";
# 			document.searchForm.method="POST";
# 			document.searchForm.submit();
# 		}else{
# 			alert("검색어를 입력 해주시기 바랍니다.");
# 			document.searchForm.searchTopTerm.focus();
# 			return false;
# 		}
# 	}
#
# 	//통합검색 페이지이동(엔터키)
# 	function fn_searchKeyTop() {
# 		if(window.event.keyCode == 13){
# 			fn_searchTop();
# 		}
# 	}
#
# 	//통합검색 인기검색어 페이지이동
# 	function fn_searchTranTop(word){
# 		$("#pc_searchTopTerm").val(word);
# 		setSearchCookie(word);
# 		document.searchForm.action="/portal/search/searchSelect.do";
# 		document.searchForm.target="_self";
# 		document.searchForm.method="post";
# 		document.searchForm.submit();
# 	}
#
# 	// 최근 검색어 클릭
# 	function termClick(keyword){
# 		$('#pc_searchTopTerm').val(keyword);
# 		fn_searchTop();
# 	};
#
# 	function fn_selectSearchDetailTerm(){
# 		for(var i = 1, ii=3; i<=ii; i++){
# 			var cmmnCd = "SD0"+i;
# 			$.ajax({
# 				data: {sysCd : "ADM", cmmnCd : cmmnCd},
# 				dataType:'json',
# 				type:'POST',
# 				async : false,
# 				url:"/ajax/common/selectCommonCode.do",
# 				success:function(arg){
# 					switch (cmmnCd){
# 						case "SD01" :
# 							for(var i = 0; i<arg.codeList.length; i++) {
# 								$(".all_search_extend .all_search_inputs_box").append("<label title=\"" + arg.codeList[i].fnprtCdNm + "\"><input type='radio' title=\"" + arg.codeList[i].fnprtCdNm + "\" name='detailCollection' value=\"" + arg.codeList[i].fnprtCd + "\">" + arg.codeList[i].fnprtCdNm + "</label>");
# 							}
# 							break;
# 						case "SD02" :
# 							for(var i = 0; i<arg.codeList.length; i++) {
# 								$("select[name='searchRange']").append("<option value=\"" + arg.codeList[i].fnprtCd + "\" name='searchRangeOption'>"+arg.codeList[i].fnprtCdNm+"</option>");
# 							}
# 							break;
# 						case "SD03"	:
# 							for(var i = 0; i<arg.codeList.length; i++) {
# 								$("select[name='searchField']").append("<option value=\"" + arg.codeList[i].fnprtCd + "\" name='searchFieldOption'>"+arg.codeList[i].fnprtCdNm+"</option>");
# 							}
# 							break;
# 						default : break;
# 					 }
# 				   },
# 				error:function(request,status,error){
# 					alert('시스템에러가 발생하였습니다. 관리자에게 문의하십시오.');
# 				}
# 			});
# 		}
# 	};
#
# 	function fn_goMinwon(){
# 		document.baseForm.action = '/minwon/myCivil.do?menu_grp=MENU_GRP21&menu_no=627';
# 		document.baseForm.target="_self";
# 		document.baseForm.method="post";
# 		document.baseForm.submit();
# 	}
#
# 	//페이지 새창오픈
# 	function fn_openPage(url , type){
# 		if(url != null && url != ''){
# 			if(type == "Y"){
# 				window.open(url, "");
# 			}else{
# 				document.baseForm.action=url;
# 				document.baseForm.target="_self";
# 				document.baseForm.method="post";
# 				document.baseForm.submit();
# 			}
# 		}
# 	}
#
# 	//권한이 없다는 메세지 띄우기
# 	function fn_Alert() {
# 		alert('기업회원이 아니거나 위임받은 인허가번호가 없어서 우리회사안전서비스를 이용할 수 없습니다.');
# 	}
# </script>
# </body>
# </html>

# %%
import requests
import json
import pandas as pd


url = 'https://www.foodsafetykorea.go.kr/portal/healthyfoodlife/searchHomeHFProc.do'

#50개 가져옴
i=50

dic={"menu_no":"2823",
     "menu_grp": "MENU_NEW01",
     "menuNm":"",
     "copyUrl":"https://www.foodsafetykorea.go.kr:443/portal/healthyfoodlife/searchHomeHF.do?menu_grp=MENU_NEW01&menu_no=2823",
     "mberld":"",
     "mberNo":"",
     "favorListCnt":"0",
     "search_code":"01",
     "search_word":"",
     "start_idx": "1",
     "show_cnt":str(i)
    }

result = []
res = requests.post(url, data=dic)
result += json.loads(res.text)


df2 = pd.DataFrame(result)
prd_no_list = df2['prdlst_report_ledg_no']
#print(df)    
print(prd_no_list)
#df.to_excel("test1.xlsx")
# Out:
# 0     2021021000400614
# 1     2021021000400388
# 2     2021021000400617
# 3     2021021000400618
# 4     2021021000400615
# 5     2021021000400938
# 6     2021021000400619
# 7     2021021000400389
# 8     2021021000400084
# 9     2021021000398811
# 10    2021021000398580
# 11    2021021000398581
# 12    2021021000398582
# 13    2021021000398583
# 14    2021021000397166
# 15    2021021000398572
# 16    2021021000398801
# 17    2021021000398802
# 18    2021021000398800
# 19    2021021000398803
# 20    2021021000396898
# 21    2021021000396901
# 22    2021021000395646
# 23    2021021000395944
# 24    2021021000395642
# 25    2021021000395644
# 26    2021021000395945
# 27    2021021000395643
# 28    2021021000395940
# 29    2021021000395943
# 30    2021021000395946
# 31    2021021000395942
# 32    2021021000395941
# 33    2021021000395948
# 34    2021021000396178
# 35    2021021000395789
# 36    2021021000395630
# 37    2021021000395629
# 38    2021021000395632
# 39    2021021000395634
# 40    2021021000395624
# 41    2021021000395633
# 42    2021021000395627
# 43    2021021000395635
# 44    2021021000395628
# 45    2021021000394956
# 46    2021021000395631
# 47    2021021000395625
# 48    2021021000395626
# 49    2021021000395788
# Name: prdlst_report_ledg_no, dtype: object

# %%
import requests
import json
import pandas as pd
from bs4 import BeautifulSoup

detailURL = 'https://www.foodsafetykorea.go.kr/portal/healthyfoodlife/searchHomeHFDetail.do'

dic={
    "prdlstReportLedgNo": prd_no_list[0],
     "search_word":"",
     "search_code":"01",
     "start_idx": "",
     "menu_no":"2823",
     "menu_grp": "MENU_NEW01",
    }

result = []
res = requests.post(detailURL, data=dic)
html_doc = res.text
soup = BeautifulSoup(html_doc, 'html.parser')
#print(soup.prettify())

cindex = []

for title in soup.find_all('th'):
    cindex.append(title.get_text()) 

cindex = cindex[2:-6]    
#print(cindex)

df = pd.DataFrame(columns=cindex)
#print(df)
for prdNo in prd_no_list:
    dic={
    "prdlstReportLedgNo": prdNo,
     "search_word":"",
     "search_code":"01",
     "start_idx": "",
     "menu_no":"2823",
     "menu_grp": "MENU_NEW01",
    }
    result = []
    res = requests.post(detailURL, data=dic)
    html_doc = res.text
    soup = BeautifulSoup(html_doc, 'html.parser')
    
    datalist = []
    for DATA in soup.find_all('td'):
        #print(DATA.get_text())
        datalist.append(DATA.get_text())
    datalist = datalist[:-3]
    #print(datalist)
    temp = pd.DataFrame(data= [datalist], columns = cindex)
    df = df.append(temp)
#print(df)
df = df.drop('등록일자', axis=1)
df = df.drop('유통기한', axis=1)
df = df.drop('포장재질(방법)', axis=1)
df = df.drop('보존 및 유통기준', axis=1)
df = df.drop('기능성 내용', axis=1)
df = df.drop('기준 및 규격', axis=1)

df['URL'] = url
df['추출 후 남은 데이터'] = "#none" #요건 그냥 추가 ㅎ 
df.rename(columns={'업소명':'제조사','신고번호':'제품코드','성상':'제형',
                   '섭취량/섭취 방법':'섭취방법','섭취시주의사항':'주의 사항'}, inplace =True)
#df = df[['제품코드','제품명','제조사','제형','섭취방법','주의 사항','URL','추출 후 남은 데이터']]

#원재료명 가져오기
rawURL = 'https://www.foodsafetykorea.go.kr/portal/healthyfoodlife/searchHfPrdlstRawmtrl.do'

rawList=[]

for CODE in df['제품코드']:
    dic={"prdlst_report_no": str(CODE)
        }
    result = []
    res = requests.post(rawURL, data=dic)
    result += json.loads(res.text)
    #print(result)
    df3 = pd.DataFrame(result)
    rString=[]
    for raws in df3['rawmtrl_nm']:
        rString.append(raws)
    rString = ",".join(rString)
    rawList.append(rString)

df['원재료명'] = rawList

cutlist=[]
for type in df['제형']:
    cutlist.append( type.split()[-1] )
#print(cutlist)
df['제형'] = cutlist

foodcode=[]
for type in df['제품코드']:
    foodcode.append("kfood-"+str(type))
df['제품코드'] = foodcode


df = df[['제품코드','제품명','제조사','제형','섭취방법','주의 사항','원재료명','URL','추출 후 남은 데이터']]

df.to_excel("result.xlsx", index = False )

print("완료")
# Out:
# 완료
